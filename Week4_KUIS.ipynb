# %% [markdown]
# <a href="https://colab.research.google.com/github/Avifahdwicahyani/PCVK_Ganjil_2023/blob/main/Week4_KUIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **KUIS**

# %%
Berapa channel/layer warna yang dimiliki oleh citra Grayscale?
A) 0
B) 1
C) 2
D) 3
E) 4
ANSWER: B
Berapakah rentang nilai keabuan yang dimiliki oleh citra 8 bit?
A) 0,1
B) 0-15
C) 0-63
D) 0-127
E) 0-255
ANSWER: E
Berapakah ukuran file untuk citra Grayscale 5-bit berukuran 640 x 640px?
A) 180 KB
B) 185 KB
C) 255 KB
D) 256 KB
E) 276 KB
ANSWER: D
Berikut adalah implementasi dari pengolahan citra digital, kecuali ...
A) Melakukan pengenalan alfabet pada plat nomor kendaraan
B) Mengidentifikasi karakteristik permukaan bumi dari citra satelit
C) Melakukan editing menggunakan Aplikasi Photoshop
D) Melakukan konversi citra analog menjadi digital
E) Melakukan penghilangan object tertentu dari citra digital
ANSWER: D
Berikut adalah pernyataan yang benar mengenai analog image / citra analog, kecuali:
A) Tidak dapat diproses komputer secara langsung
B) Didapatkan dari alat-alat analog seperti camera video, camera foto, dll
C) Gambar yang tercetak ataupun gambar yang berasal dari monitor TV
D) Gambar Continous
E) Gambar diskrit
ANSWER: E
Berikut ini yang merupakan jenis operasi citra adalah:	* point operation	* matrix operation	* area operation	* histogram operation	* global operation
A) 1,2,5
B) 2,4,5
C) 1,3,5
D) 1,2,3
E) 1,3,4
ANSWER: C
Cara mengekstrak warna hijau pada sebuah citra RGB menggunakan python adalah:
A) color_img[:,:,0]
B) color_img[:,:,1]
C) color_img[:,:,2]
D) color_img[:,0,0]
E) color_img[:,0,1]
ANSWER: B
Citra 5-bit pada pixel warna 25, jika diinverse akan menghasilkan warna ...
A) 230
B) 228
C) 26
D) 225
E) 27
ANSWER: C
Citra Digital 5-bit memiliki jumlah kuantisasi ...
A) 7
B) 16
C) 32
D) 15
E) 31
ANSWER: C
Citra RGB 4-bit memiliki kemungkinan jumlah warna ...
A) 15
B) 4096
C) 255
D) 16
E) 16.777.216
ANSWER: B
Dari potongan kode program berikut, manakah yang akan memberikan output berupa tambahan shape persegi panjang warna hijau pada gambar..
A) cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
B) cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,0,255),thickness=10)
C) cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(255,255,0),thickness=10)
D) cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(255,0,0),thickness=10)
E) cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,0,0),thickness=10)
ANSWER: A
Efek sampling dari akuisisi citra akan berpengaruh pada...
A) informasi warna tepian objek yang tertangkap menjadi hilang sebagian
B) jumlah warna pixel menjadi sesuai jumlah 2^bitdepth
C) Informasi ukuran pixel yang sesuai jumlah bit kuantisasi
D) Informasi warna pixel terbatas pada jumlah CCD Array dari kamera
E) Ukuran citra yang berbanding dengan ukuran object yang tertangkap kamera
ANSWER: A
Formula yang digunakan untuk membalik nilai derajat keabuan dimana titik terang akan menjadi gelap dan titik gelap akan menjadi terang (inverse color) adalah:
A) g(x,y)=f(x,y)+b
B) g(x,y)=a* f(x,y)+b
C) s=c* log(1+r)
D) g(x)=0.21𝑅+0.72𝐺+0.07𝐵
E) g(x)=255-f(x)
ANSWER: E
Image greyscale 24bit dengan resolusi 1024x640, Berapakah ukuran Filenya?
A) 3000KB
B) 3145KB
C) 1920KB
D) 1204KB
E) 2165KB
ANSWER: C
image.shape[0] pada python menyatakan:
A) koordinat image
B) lebar sebuah image
C) tinggi sebuah image
D) channel merah pada image
E) channel biru pada image
ANSWER: C
Intentisas cahaya suatu citra disebut dengan...
A) Contrast
B) Brightness
C) Contour
D) Color
E) Shape
ANSWER: B
Jika terdapat gambar 512 x 512 pixel, bagaimana kode yang benar untuk menambahkan garis diagonal dari kiri atas ke kanan bawah?
A) cv.line(black_img,pt1=(512,512),pt2=(0,0),color=(255,255,255),thickness=5)plt.imshow(black_img)
B) cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)plt.imshow(black_img)
C) cv.line(black_img,pt1=(511,511),pt2=(0,0),color=(255,255,255),thickness=5)plt.imshow(black_img)
D) cv.line(black_img,pt1=(0,0),pt2=(511,511),color=(255,255,255),thickness=5)plt.imshow(black_img)
E) Semua jawaban salah
ANSWER: B
Manakah library python berikut yang berikaitan dengan pembentukan objek N-dimensional array?
A) OpenCV
B) NumPy
C) Pandas
D) CV2
E) Skimage
ANSWER: B
Manakah pernyataan berikut yang salah mengenai grayscale image...
A) Grayscale image 1 bit sama dengan gambar monochrome
B) Grayscale image 8 bit terdiri dari 255 gradasi warna
C) Digitalisasi Grayscale image terdiri dari 1 bit terdiri dari angka 0 dan 1
D) Digitalisasi Grayscale image 8 bit terdiri dari angka 0 sampai 7
E) Grayscale image tidak memiliki warna lain selain warna antara hitam dan putih
ANSWER: B
Manakah potongan kode program berikut yang digunakan untuk mengetahui resolusi sebuah gambar...
A) tinggi = image_2.lengthlebar = image_2.widthprint("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
B) tinggi = image_2.shape[length]lebar = image_2.shape[width]print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
C) tinggi = image_2.shape1lebar = image_2.shape2print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
D) tinggi = image_2.shape[0]lebar = image_2.shape[1]print("resolusi image: length x width = ",tinggi," x ",lebar)
E) tinggi = image_2.shape[1]lebar = image_2.shape[2]print("resolusi image: length x width = ",tinggi," x ",lebar)
ANSWER: D
Manakah potongan kode program yang benar untuk resize gambar sebesar 50% dari ukuran awal gambar...
A) image = cv.resize(image, (512,512), fx=50%, fy=50%)
B) image = cv.resize(image, (0,0), fx=50%, fy=50%)
C) image = cv.resize(image, (512,512), fx=0.5, fy=0.5)
D) image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
E) Semua jawaban salah
ANSWER: D
Manakah urutan akuisisi gambar digital yang paling benar?	* Sumber iluminasi	* Scene Elemen	* Arus Listrik	* Konverter Data Digital	* Gambar Digital	* Sensor Imaging System	* Bidang Gambar	* Pantulan Cahaya
A) 1-2-6-8-7-3-4-5
B) 1-2-8-6-7-5-4-3
C) 1-2-8-6-7-3-4-5
D) 1-2-6-8-7-5-4-3
E) 1-2-3-4-5-6-7-8
ANSWER: C
Manakah potongan kode program berikut yang digunakan untuk menampilkan gambar pada channel Red-Blue saja...
A) img3[:,:,1:2] = 0
B) img3[:,:,0:1] = 0
C) img3[:,:,0:2] = 0
D) img3[:,:,2] = 0
E) img3[:,:,1] = 0
ANSWER: E
Notasi f(120,10) = 237 pada citra digital menyatakan:
A) piksel pada kolom 120 dan baris 10 memiliki nilai keabuan sebesar 237
B) piksel pada baris 120 dan kolom 10 memiliki nilai keabuan sebesar 237
C) piksel pada kolom 120 dan baris 10 memiliki nilai kedalaman sebesar 237 bit
D) piksel pada baris 120 dan kolom 10 memiliki nilai kedalaman sebesar 237 bit
E) citra berukuran 120x10 piksel memiliki nilai keabuan sebesar 237
ANSWER: B
Pembagian skala keabuan menjadi derajat keabuan (G level), merupakan pengertian dari
A) sampling
B) kuantisasi
C) resolusi
D) kontras
E) konversi citra
ANSWER: B
Salah satu metode pengolahan citra yang termasuk dalam area operation adalah
A) edge detection
B) histogram equalization
C) linier brightness
D) contrast
E) inverse color
ANSWER: A
Sebaran terang dan gelap pada sebuah gambar disebut
A) sampling
B) kuantisasi
C) resolusi
D) kontras
E) konversi citra
ANSWER: D
Suatu Pixel bernilai R=50, G=130, B=70. dengan konstanta=40, Berapakah nilai Log Brightnessnya?
A) R=60, G=80, B=74
B) R=68, G=85, B=74
C) R=68, G=87, B=74
D) R=70, G=87, B=74
E) R=68, G=87, B=80
ANSWER: B
Suatu Pixel bernilai R=60, G=175, B=55. Berapakah nilai Grayscale Lightnessnya?
A) 90
B) 115
C) 109
D) 110
E) 83
ANSWER: B
Warna kuning dalam pixel akan diwakili oleh nilai ....
A) R=0xFE, G=0xAA, B=0xFF
B) R=0x00, G=0xAA, B=0xFF
C) R=0xFE, G=0x00, B=0xFF
D) R=0xFF, G=0xFF, B=0x00
E) R=0xFF, G=0xFF, B=0xFF
ANSWER: D
